# %%
#Primero opcupo drive para trabajar con la bd que puse en la carpeta
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#importo librerías que voy a utilizar
import pandas as pd
import numpy as np
from google.colab import files

# %%
#Ahora leo la información del excel que guardamos
data =  pd.read_excel('/content/drive/MyDrive/sources-abortion.xlsx')
# Out:
# 286

# %%
#leo las primeras 10 filas
data.head(10)
# Out:
#   Member State (States/Entities)  Reproductive Health Act  \
# 0                     Afghanistan                     NaN
# 1                         Albania                     NaN
# 2                         Algeria                     NaN
# 3                         Andorra                     NaN
# 4                          Angola                     NaN
# 5             Antigua and Barbuda                     NaN
# 6                       Argentina                     NaN
# 7                         Armenia                       X
# 8                       Australia                     NaN
# 9   Australia - Capital Territory                     NaN
#
#   General Medical Health Act Constitution Criminal/ Penal Code Civil Code  \
# 0                        NaN          NaN                    X        NaN
# 1                        NaN          NaN                    X        NaN
# 2                          X          NaN                    X        NaN
# ...

# %% [markdown]
# **Como no podemos trabajar con estos datos necesitamos limpiarlos**
#
# ---

# %%
# Reemplazo todos los nan(not a number) por un 0
data.fillna(value=0, inplace=True)

# Reemplazo todos los X por un 1
data = data.replace('X', 1)

# %%
data.head(10)
# Out:
#   Member State (States/Entities)  Reproductive Health Act  \
# 0                     Afghanistan                       0
# 1                         Albania                       0
# 2                         Algeria                       0
# 3                         Andorra                       0
# 4                          Angola                       0
# 5             Antigua and Barbuda                       0
# 6                       Argentina                       0
# 7                         Armenia                       1
# 8                       Australia                       0
# 9   Australia - Capital Territory                       0
#
#    General Medical Health Act  Constitution  Criminal/ Penal Code  Civil Code  \
# 0                           0             0                     1           0
# 1                           0             0                     1           0
# 2                           1             0                     1           0
# ...

# %%
#Ahora descargo mi nueva base de datos limpiada
data.to_csv('GlobalAbortionPoliciesDatabase.csv', index=False)
files.download('GlobalAbortionPoliciesDatabase.csv')
